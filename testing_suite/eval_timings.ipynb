# %%
import sys
sys.dont_write_bytecode = True
import numpy as np
from testing_suite import *
from parameters import *
from algorithm import *
import functions as fcn
import time
import matplotlib.pyplot as plt
import math
import itertools
import random as rand

# %%
f=open("timings_5gen_10pop_1.txt",'r')
s = f.read()
f.close()
s = s.split('\n')
s = np.array([ss[20:-1].split() for ss in s]).astype(float).transpose()
s[0] = s[0]/5
s = np.append(s, [s[0]-np.sum(s[1:], axis=0)], axis=0)
print(s)
titles = ['total','selection','mutation','shuffle','crossover','fitness','total - rest (save, counter, loop)']

for i in range(0,s.shape[0]):
    ss = s[i]
    weights = np.ones_like(ss) / ss.size
    plt.figure(1)
    plt.hist(ss, weights=weights, rwidth=.9)
    plt.title(titles[i])
    plt.xlabel('time (s)')
    plt.show()
    print(np.mean(ss))
# Out:
# [[0.07287372 0.07080554 0.0719504  ... 0.07137008 0.07187978 0.07499264]
#  [0.0037973  0.003861   0.0037054  ... 0.0038449  0.0038086  0.0037786 ]
#  [0.0236848  0.0238511  0.0236973  ... 0.0244699  0.0244247  0.0245038 ]
#  ...
#  [0.0008945  0.0010379  0.0008044  ... 0.0015766  0.0014155  0.0014219 ]
#  [0.0357138  0.0354594  0.0353253  ... 0.0356679  0.0354532  0.0357586 ]
#  [0.00545642 0.00325664 0.0051066  ... 0.00241448 0.00343298 0.00619884]]
# 0.07176492260416667
# 0.003843251041666667
# 0.0242604375
# 0.0033320822916666666
# 0.0011498468750000001
# 0.035702044791666665
# 0.0034772601041666656

# %%
f=open("timings_5gen_10pop_2.txt",'r')
s = f.read()
f.close()
s = s.split('\n')
s = np.array([ss[20:-1].split() for ss in s]).astype(float).transpose()
s[0] = s[0]/5
s = np.append(s, [s[0]-np.sum(s[1:], axis=0)], axis=0)
print(s)
titles = ['total','selection','mutation','shuffle','crossover','fitness','total - rest (save, counter, loop)']

for i in range(0,s.shape[0]):
    ss = s[i]
    weights = np.ones_like(ss) / ss.size
    plt.figure(2)
    plt.hist(ss, weights=weights, rwidth=.9)
    plt.title(titles[i])
    plt.xlabel('time (s)')
    plt.show()
    print(np.mean(ss))
# Out:
# [[0.0756567  0.07280466 0.07411478 ... 0.07285294 0.0745753  0.07266906]
#  [0.0043796  0.0041873  0.004026   ... 0.0043382  0.0044931  0.0042866 ]
#  [0.0242755  0.0245715  0.0241374  ... 0.025838   0.0251705  0.0253092 ]
#  ...
#  [0.0006393  0.0009233  0.0011906  ... 0.00072    0.0010469  0.0011234 ]
#  [0.0356803  0.0356878  0.0354885  ... 0.0358277  0.0360553  0.0363003 ]
#  [0.0075173  0.00428546 0.00634138 ... 0.00311244 0.0045232  0.00241476]]
# 0.073801506875
# 0.004542005729166667
# 0.02541477916666667
# 0.0033035656249999997
# 0.0009685421875
# 0.036071916145833334
# 0.0035006980208333338

# %%
f=open("timings_5gen_10pop_3.txt",'r')
s = f.read()
f.close()
s = s.split('\n')
s = np.array([ss[20:-1].split() for ss in s]).astype(float).transpose()
s[0] = s[0]/5
s = np.append(s, [s[0]-np.sum(s[1:], axis=0)], axis=0)
print(s)
titles = ['total','selection','mutation','shuffle','crossover','fitness','total - rest (save, counter, loop)']

for i in range(0,s.shape[0]):
    ss = s[i]
    weights = np.ones_like(ss) / ss.size
    plt.figure(2)
    plt.hist(ss, weights=weights, rwidth=.9)
    plt.title(titles[i])
    plt.xlabel('time (s)')
    plt.show()
    print(np.mean(ss))
# Out:
# [[0.07041796 0.06972438 0.0721025  ... 0.07361566 0.07093108 0.07569386]
#  [0.0051732  0.0044216  0.0046834  ... 0.0053832  0.0045722  0.0044909 ]
#  [0.021626   0.0207197  0.0219747  ... 0.0221538  0.0219909  0.0246221 ]
#  ...
#  [0.0005453  0.00063    0.000486   ... 0.0011787  0.0012601  0.0012104 ]
#  [0.0360277  0.035996   0.0360918  ... 0.0374841  0.036168   0.037213  ]
#  [0.00407326 0.00495428 0.0058516  ... 0.00430536 0.00353468 0.00462106]]
# 0.07339362385416666
# 0.005061688541666666
# 0.022851872395833334
# 0.0032441677083333335
# 0.0010047223958333333
# 0.036479728125
# 0.0047514446875
