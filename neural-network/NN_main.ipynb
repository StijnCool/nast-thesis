# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import NN_internals as NNi

# %%
pinn = NNi.train_model(EPOCHS = 30000, print_every = 1000)
# Out:
# Epoch 0, Loss: 1.3576e-03
# Epoch 1000, Loss: 1.1964e-05
# Epoch 2000, Loss: 1.3258e-05
# Epoch 3000, Loss: 1.4632e-05
# Epoch 4000, Loss: 1.1165e-05
# Epoch 5000, Loss: 1.0419e-05
# Epoch 6000, Loss: 1.3002e-05
# Epoch 7000, Loss: 1.4959e-05
# Epoch 8000, Loss: 1.1797e-05
# Epoch 9000, Loss: 1.4014e-05
# Epoch 10000, Loss: 1.3850e-05
# Epoch 11000, Loss: 1.2670e-05
# Epoch 12000, Loss: 1.1077e-05
# Epoch 13000, Loss: 1.0854e-05
# Epoch 14000, Loss: 1.1865e-05
# Epoch 15000, Loss: 1.2611e-05
# Epoch 16000, Loss: 1.3731e-05
# Epoch 17000, Loss: 1.0529e-05
# Epoch 18000, Loss: 1.4247e-05
# Epoch 19000, Loss: 1.7537e-05
# Epoch 20000, Loss: 1.3574e-05
# Epoch 21000, Loss: 1.2115e-05
# Epoch 22000, Loss: 1.0976e-05
# Epoch 23000, Loss: 1.5161e-05
# Epoch 24000, Loss: 1.1933e-05
# Epoch 25000, Loss: 1.1422e-05
# Epoch 26000, Loss: 1.2956e-05
# Epoch 27000, Loss: 1.4829e-05
# Epoch 28000, Loss: 1.1439e-05
# Epoch 29000, Loss: 1.4134e-05

# %%
u0 = torch.tensor(343 / (288 * np.pi))
v0 = torch.tensor(-49 / (288 * np.pi))

# %%
NNi.plot_results(pinn)
# Out:
# Neural network solution at v = -0.078
